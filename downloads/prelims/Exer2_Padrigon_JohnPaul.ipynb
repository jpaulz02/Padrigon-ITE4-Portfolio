# %% [markdown]
# ## Install necessary libraries

# %%
#installer

# %% [markdown]
# ## Importing libraries
#
# In this cell, it uses the pandas library to load and preview the dataset. The code "from google.colab import drive" is used to call out the location where the dataset could be located which is google drive. "drive.mount('/content/drive')
# df = pd.read_csv('/content/drive/MyDrive/data_supervised.csv')" this code pin points the exact location which the dataset can be found in the google drive. Then the df.head() runs or print the first five contents of the dataset.

# %%
import pandas as pd
#import dataset
from google.colab import drive
drive.mount('/content/drive')
df = pd.read_csv('/content/drive/MyDrive/the_japan_times_data_1_2022_05.csv')
#check the first 5 instances
df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
#                                             headline     author  \
# 0  China’s Xi leaves Zelenskyy out of Ukraine dip...  No Author
# 1  MoonJae-in to focus on victims in 'comfort wom...        NaN
# 2  Abandoned boats pose tsunami hazard at Nagoya ...  No Author
# 3  NSA surveillance powers lapse after no deal in...  No Author
# 4       Mamma mia! Nintendo to open archive in Kyoto        NaN
#
#              category                                            article
# 0               World  Chinese President Xi Jinping has held a flurry...
# 1            National  CHEONAN, South Korea – South Korean President ...
# 2            National  Nagoya authorities are worried that the more t...
# 3      Politics,World  WASHINGTON – Three U.S. spy programs aimed at ...
# 4  Corporate,Business  After opening its first theme park area in Mar...

# %% [markdown]
# # Pipeline
# # ----------------------------------------------
# ## 1. Lowercasing
# ## 2. Special Character Removal
# ## 3. Stopword Removal
# ## 4. Tokenization

# %% [markdown]
# # ---------------------------------------------------

# %% [markdown]
# # Lowercasing Dataset
#
# In this cell, it extracted the first article (or whatever content is in that first row of the 'Article' column) and saved it as test_case, which you can now use for testing or further analysis.

# %%
#testing for a single case
test_case = df['headline'][1]
print(test_case)
# Out:
# MoonJae-in to focus on victims in 'comfort women' row with Japan

# %% [markdown]
# In this cell it used the "lower()" method in the test_case which contains the first entry in the collumn article. All text are transformed into lower case.

# %%
test_case = test_case.lower()
print(test_case)
# Out:
# moonjae-in to focus on victims in 'comfort women' row with japan

# %% [markdown]
# In this cell, it applies the lower casing method which is "lower()". It also used lambda function to apply the lower casing method to every entry in the dataset. Then the df.head(10) prints the first 10 entries to check or verify if the lower casing method was applied correctly

# %%
#applying it to the dataset
df['article'] = df['article'].apply(lambda x: str(x).lower())
df['headline'] = df['headline'].apply(lambda x: str(x).lower())
df['category'] = df['category'].apply(lambda x: str(x).lower())
#checking for first 10 instances
df.head(10)
# Out:
#                                             headline        author  \
# 0  chinas xi leaves zelenskyy out of ukraine dipl...     No Author
# 1  moonjaein to focus on victims in comfort women...           NaN
# 2  abandoned boats pose tsunami hazard at nagoya ...     No Author
# 3  nsa surveillance powers lapse after no deal in...     No Author
# 4        mamma mia nintendo to open archive in kyoto           NaN
# 5         russia officers aiding rebels ukraine says     No Author
# 6  poaching of glass eels on the rise in japan am...     No Author
# 7  nations regional banks facing choice of merger...  Gareth Allan
# 8  japan still on fence about aiib but envisages ...     No Author
# 9  imperial couple release waka poems to mark new...     No Author
#
#             category                                            article
# 0              world  chinese president xi jinping has held a flurry...
# 1           national  cheonan south korea  south korean president mo...
# 2           national  nagoya authorities are worried that the more t...
# 3      politicsworld  washington  three us spy programs aimed at sto...
# 4  corporatebusiness  after opening its first theme park area in mar...
# 5      politicsworld  kiev  ukraine accused russian army officers on...
# 6           national  kochi  japan is struggling to crack down on th...
# 7           business  hiroshi iwama and mitsunori watanabe used to j...
# 8           business  the government does not rule out the possibili...
# 9           national  the imperial household agency released on thur...

# %% [markdown]
# # Special Character Removal
#
# It prints again the test_case which contains the first entry in the dataset

# %%
#testing for a single case
print(test_case)
# Out:
# moonjae-in to focus on victims in 'comfort women' row with japan

# %% [markdown]
# Here it uses the library "re" or "regular expression" which then applied to test_case. Its purpose is to remove the special characters in the text.

# %%
#import library regex
import re
#remove all instances that aren't a-z or 0-9
test_case = re.sub("[^a-zA-Z0-9\s]",'',test_case)
print(test_case)
# Out:
# moonjaein to focus on victims in comfort women row with japan

# %% [markdown]
# Then this cell also uses lambda function to apply the library re to remove the special characters to all entries in the collumn "article" in the dataset. Lastly it prints the first 10 entry using df.head(10) to check and verify if the removal of special characters are correctly implemented.

# %%
#apply to all
df['article'] = df['article'].apply(lambda x: re.sub("[^a-zA-Z0-9\s]",'',x))
df['headline'] = df['headline'].apply(lambda x: re.sub("[^a-zA-Z0-9\s]",'',x))
df['category'] = df['category'].apply(lambda x: re.sub("[^a-zA-Z0-9\s]",'',x))
df.head(10)
# Out:
#                                             headline        author  \
# 0  chinas xi leaves zelenskyy out of ukraine dipl...     No Author
# 1  moonjaein to focus on victims in comfort women...           NaN
# 2  abandoned boats pose tsunami hazard at nagoya ...     No Author
# 3  nsa surveillance powers lapse after no deal in...     No Author
# 4        mamma mia nintendo to open archive in kyoto           NaN
# 5         russia officers aiding rebels ukraine says     No Author
# 6  poaching of glass eels on the rise in japan am...     No Author
# 7  nations regional banks facing choice of merger...  Gareth Allan
# 8  japan still on fence about aiib but envisages ...     No Author
# 9  imperial couple release waka poems to mark new...     No Author
#
#             category                                            article
# 0              world  chinese president xi jinping has held a flurry...
# 1           national  cheonan south korea  south korean president mo...
# 2           national  nagoya authorities are worried that the more t...
# 3      politicsworld  washington  three us spy programs aimed at sto...
# 4  corporatebusiness  after opening its first theme park area in mar...
# 5      politicsworld  kiev  ukraine accused russian army officers on...
# 6           national  kochi  japan is struggling to crack down on th...
# 7           business  hiroshi iwama and mitsunori watanabe used to j...
# 8           business  the government does not rule out the possibili...
# 9           national  the imperial household agency released on thur...

# %% [markdown]
# # Stop word Removal
#
# ### Example english stopwords:
# #### the, is, and
# ### Example tagalog stopwords:
# #### at, pala, kaya
#
# It imports the module "stopwords" from the library nltk.corpus. NLTK means Natural Language Toolkit

# %%
from nltk.corpus import stopwords

# %% [markdown]
# Prints the english stopwords.
#
# Note that the dataset only contains English language
#
# Stopwords from other languages, such as Tagalog, are not necessary to include if the sole text in your dataset is English. Although adding stopwords from another language won't take up much room, the software will have to check words that aren't even in your dataset, which could slow down the process. It's also possible to unintentionally eliminate words that are crucial to the English language by employing stopwords from another language. You wouldn't want to lose knowledge of a word that, for instance, is significant in English but meaningless in Tagalog.

# %%
import nltk
nltk.download('stopwords')
#download and import english stopwords
stop_words = stopwords.words('english')
print(stop_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Import the file containing text of tagalog stopwords from google drive and prints it.

# %% [markdown]
# ### Removing all stopwords from the dataset
#
# Printing the first entry for reference or checking for the next code which would be the removal of stopwords

# %%
#testing it for a single case
print(test_case)
# Out:
# moonjaein to focus on victims in comfort women row with japan

# %% [markdown]
# Here we apply a simple text pre-processing techniques. test_case.split(' ') splits the words base on the spaces between each words.
#
# In this code, the loop goes through each word in the text, checking for three things: if the word is empty (from extra spaces), if it contains a line break (\r\n), or if it's a stopword like "the" or "and." If any of these are true, the word is skipped. Otherwise, it's added to the final_test list. After the loop, print(final_test) shows you the cleaned-up list of meaningful words, with all the unnecessary ones removed.

# %%
#split the text per space
#print(test_case.split(' '))
#initialize empty list for finalization of stopword removal
final_test =[]
#remove all empty and \r\n
for word in test_case.split():
    if word =='' or '\r\n' in word or word in stop_words:
        None
    else:
        final_test.append(word)
print(final_test)
# Out:
# ['moonjaein', 'focus', 'victims', 'comfort', 'women', 'row', 'japan']

# %% [markdown]
# It joins all the meaninful words in one paragraph. Just like the original entry. The differnce is stopwords are removed. In other words it successfully pre-processed the text.

# %%
#lets try to join the final test
' '.join(final_test)
# Out:
# 'moonjaein focus victims comfort women row japan'

# %% [markdown]
# ## Applying to dataset
#
# This is the part where we apply it to the whole dataset.
#
# "remove_stopwords" cleans up an article by removing any stopwords, empty spaces, and line breaks. It splits the article into words, filters out the unwanted ones, and then joins the remaining words back into a cleaned-up string. The result is a more focused version of the text, free of unnecessary words.

# %%
#make a function pipeline:
def remove_stopwords(article,stopwords):
    #make a temporary list
    temp_fnl = []
    for word in article.split():
        if word =='' or '\r\n' in word or word in stopwords:
            None
        else:
            temp_fnl.append(word)
    return ' '.join(temp_fnl)

# %%
remove_stopwords(test_case,stop_words)
# Out:
# 'moonjaein focus victims comfort women row japan'

# %% [markdown]
# Apply to the whole entries in the article which also, again uses lambda function

# %%
#apply to the whole dataset
df['article'] = df['article'].apply(lambda x: remove_stopwords(x, stop_words))
df['headline'] = df['headline'].apply(lambda x: remove_stopwords(x, stop_words))
df['category'] = df['category'].apply(lambda x: remove_stopwords(x, stop_words))
df.head(10)
# Out:
#                                             headline        author  \
# 0  chinas xi leaves zelenskyy ukraine diplomatic ...     No Author
# 1    moonjaein focus victims comfort women row japan           NaN
# 2    abandoned boats pose tsunami hazard nagoya port     No Author
# 3          nsa surveillance powers lapse deal senate     No Author
# 4              mamma mia nintendo open archive kyoto           NaN
# 5         russia officers aiding rebels ukraine says     No Author
# 6  poaching glass eels rise japan amid surging pr...     No Author
# 7  nations regional banks facing choice mergers e...  Gareth Allan
# 8  japan still fence aiib envisages 15 billion co...     No Author
# 9  imperial couple release waka poems mark new ye...     No Author
#
#             category                                            article
# 0              world  chinese president xi jinping held flurry talks...
# 1           national  cheonan south korea south korean president moo...
# 2           national  nagoya authorities worried 100 abandoned boats...
# 3      politicsworld  washington three us spy programs aimed stoppin...
# 4  corporatebusiness  opening first theme park area march nintendo c...
# 5      politicsworld  kiev ukraine accused russian army officers mon...
# 6           national  kochi japan struggling crack poaching glass ee...
# 7           business  hiroshi iwama mitsunori watanabe used joke mer...
# 8           business  government rule possibility joining chinaled d...
# 9           national  imperial household agency released thursday se...

# %% [markdown]
# ## Tokenization
#
# Running nltk.download('punkt') downloads the "punkt" package, which helps with tokenizing text—splitting it into words or sentences. This step is key in natural language processing, making it easier to break down and analyze text.

# %%
import nltk
nltk.download('punkt')  # Download the necessary data for tokenization
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# This line imports the word_tokenize function from NLTK, which you can use to split text into individual words.

# %%
from nltk.tokenize import word_tokenize

# %% [markdown]
# This code uses word_tokenize to split each article in the 'Article' column into individual words, storing the result in a new column called 'tokenized_article'.

# %%
# Apply word_tokenize function to each article in the 'article' column
df['tokenized_article'] = df['article'].apply(word_tokenize)

# %% [markdown]
# Printing the first 10 entries of the tokenized article. For checking and verifying results if the code works properly.

# %%
# Print the first 10 tokenized result
df['tokenized_article'].head(10)
# Out:
# 0    [chinese, president, xi, jinping, held, flurry...
# 1    [cheonan, south, korea, south, korean, preside...
# 2    [nagoya, authorities, worried, 100, abandoned,...
# 3    [washington, three, us, spy, programs, aimed, ...
# 4    [opening, first, theme, park, area, march, nin...
# 5    [kiev, ukraine, accused, russian, army, office...
# 6    [kochi, japan, struggling, crack, poaching, gl...
# 7    [hiroshi, iwama, mitsunori, watanabe, used, jo...
# 8    [government, rule, possibility, joining, china...
# 9    [imperial, household, agency, released, thursd...
# Name: tokenized_article, dtype: object
